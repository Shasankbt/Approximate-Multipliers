# %%
from torch.utils.cpp_extension import load
import torch

# 1. Compile
# Make sure the file above is saved as "pbom8-73y/pbo_float.cpp"
pbo_cpp = load(name="pbo_extension", sources=["pbom8-73y/pbo_float.cpp"], verbose=True)

# 2. Test Data (2D Tensors)
a = torch.tensor([[2.2, 4.5], [10.0, 3.4]], dtype=torch.float32)
b = torch.tensor([[1.5, 2.0], [5.0, 3.2]], dtype=torch.float32)

# 3. Run
print("Exact Math:\n", a * b)
approx_output = pbo_cpp.pbo_product(a, b)
print("\nApproximate BFloat16 Math:\n", approx_output)
# Out:
# Using /home/shasankbt/.cache/torch_extensions/py313_cpu as PyTorch extensions root...
# Emitting ninja build file /home/shasankbt/.cache/torch_extensions/py313_cpu/pbo_extension/build.ninja...
# Building extension module pbo_extension...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# [1/2] c++ -MMD -MF pbo_float.o.d -DTORCH_EXTENSION_NAME=pbo_extension -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1019\" -isystem /home/shasankbt/miniconda3/envs/approx-multiplier-env/include -isystem /home/shasankbt/miniconda3/envs/approx-multiplier-env/include/torch/csrc/api/include -isystem /home/shasankbt/miniconda3/envs/approx-multiplier-env/lib/python3.13/site-packages/torch/include -isystem /home/shasankbt/miniconda3/envs/approx-multiplier-env/include/python3.13 -D_GLIBCXX_USE_CXX11_ABI=1 -fPIC -std=c++17 -c /home/shasankbt/Projects/Approximate-Multipliers/pbom8-73y/pbo_float.cpp -o pbo_float.o
# [2/2] c++ pbo_float.o -shared -L/home/shasankbt/miniconda3/envs/approx-multiplier-env/lib -lc10 -ltorch_cpu -ltorch -ltorch_python -o pbo_extension.so
# Exact Math:
#  tensor([[ 3.3000,  9.0000],
#         [50.0000, 10.8800]])
#
# Approximate BFloat16 Math:
#  tensor([[ 3.6250, 12.5625],
#         [58.5000,  5.4688]])
# Loading extension module pbo_extension...
